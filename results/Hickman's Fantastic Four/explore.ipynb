# %%
import pandas as pd

# %%
edges = pd.read_csv('data/edge_list.csv')
print(edges.shape)
edges.head()
# Out:
# (16512, 3)
#            source             target  correlation
# 0  Fantastic Four   Mister Fantastic     0.350877
# 1  Fantastic Four        Susan Storm     0.460745
# 2  Fantastic Four     Jonathan Storm     0.825186
# 3  Fantastic Four          The Thing     0.624247
# 4  Fantastic Four  Franklin Richards     0.171383

# %%
edges.shape[0] ** 0.5
# Out:
# 128.49902723367208

# %%
edges
# Out:
#                source             target  correlation
# 0      Fantastic Four   Mister Fantastic     0.350877
# 1      Fantastic Four        Susan Storm     0.460745
# 2      Fantastic Four     Jonathan Storm     0.825186
# 3      Fantastic Four          The Thing     0.624247
# 4      Fantastic Four  Franklin Richards     0.171383
# ...               ...                ...          ...
# 16507            Bast     Angelica Jones    -0.038462
# 16508            Bast       Anya Corazon    -0.038462
# 16509            Bast              Onome    -0.055470
# 16510            Bast              Shuri     0.808608
# 16511            Bast             Anubis     1.000000
#
# [16512 rows x 3 columns]

# %%
edges.sort_values("correlation", ascending=False).groupby('source').head(3)
# Out:
#                                  source                       target  \
# 8256                           Prax Ord                   Els Udonta
# 14576                             Ronan          Crystalia Amaquelin
# 8642                              Voorr                  Dara Ko Eke
# 8901          Cult of the Negative Zone                  Anti-Priest
# 9029                        Anti-Priest    Cult of the Negative Zone
# ...                                 ...                          ...
# 16039                             Onome                Korr (Moloid)
# 16036                             Onome                Turg (Moloid)
# 16043                             Onome                          Vil
# 10000  Nathaniel Richards (Earth-12498)           Nathaniel Richards
# 2701         Victor von Doom (Earth-45)  Reed Richards (Earth-98570)
#
#        correlation
# 8256      1.000000
# 14576     1.000000
# 8642      1.000000
# 8901      1.000000
# 9029      1.000000
# ...

# %%
edges
# Out:
#                source             target  correlation
# 0      Fantastic Four   Mister Fantastic     0.350877
# 1      Fantastic Four        Susan Storm     0.460745
# 2      Fantastic Four     Jonathan Storm     0.825186
# 3      Fantastic Four          The Thing     0.624247
# 4      Fantastic Four  Franklin Richards     0.171383
# ...               ...                ...          ...
# 16507            Bast     Angelica Jones    -0.038462
# 16508            Bast       Anya Corazon    -0.038462
# 16509            Bast              Onome    -0.055470
# 16510            Bast              Shuri     0.808608
# 16511            Bast             Anubis     1.000000
#
# [16512 rows x 3 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\Library\Documents\GitHub\web-of-marvel-characters\results\Hickman's Fantastic Four\explore.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Library/Documents/GitHub/web-of-marvel-characters/results/Hickman%27s%20Fantastic%20Four/explore.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> from utils import prepare_edges
#
# ModuleNotFoundError: No module named 'utils'
