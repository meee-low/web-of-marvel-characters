# %%
import pandas as pd

# %%
char_stats = pd.read_csv("data/character_stats.csv")

# %%
char_stats.head()
# Out:
#               character name  Appearances  Minor Appearances  Mentions  \
# 0                      Conan           25                  1         0
# 1      Kulan Gath (Impostor)           16                  3         2
# 2  Wolverine (James Howlett)           13                  1         3
# 3             Doctor Strange           13                  1         3
# 4           Elektra Natchios           12                  2         2
#
#    Total Appearances (Full and Minor)  \
# 0                                  26
# 1                                  19
# 2                                  14
# 3                                  14
# 4                                  14
#
#    Appearances and Mentions (Full + Minor + Mentions)
# 0                                                 26
# 1                                                 21
# 2                                                 17
# 3                                                 17
# ...

# %%
char_stats.describe()
# Out:
#        Appearances  Minor Appearances    Mentions  \
# count   173.000000         173.000000  173.000000
# mean      1.768786           0.341040    0.520231
# std       3.120405           0.750498    0.937523
# min       0.000000           0.000000    0.000000
# 25%       0.000000           0.000000    0.000000
# 50%       1.000000           0.000000    0.000000
# 75%       2.000000           0.000000    1.000000
# max      25.000000           4.000000    6.000000
#
#        Total Appearances (Full and Minor)  \
# count                          173.000000
# mean                             2.109827
# std                              3.415860
# min                              0.000000
# 25%                              1.000000
# 50%                              1.000000
# 75%                              2.000000
# max                             26.000000
#
#        Appearances and Mentions (Full + Minor + Mentions)
# count                                         173.000000
# ...

# %%
char_stats
# Out:
#                 character name  Appearances  Minor Appearances  Mentions  \
# 0                        Conan           25                  1         0
# 1        Kulan Gath (Impostor)           16                  3         2
# 2    Wolverine (James Howlett)           13                  1         3
# 3               Doctor Strange           13                  1         3
# 4             Elektra Natchios           12                  2         2
# ..                         ...          ...                ...       ...
# 168                      Knull            0                  3         0
# 169      Kulan Gath (Original)            0                  1         0
# 170                   Mephisto            0                  0         2
# 171                Ogun (Vodū)            0                  0         1
# 172       Conan (Earth-TRN767)            0                  0         1
#
#      Total Appearances (Full and Minor)  \
# 0                                    26
# ...
